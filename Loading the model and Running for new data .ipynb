# %%
import pickle
import pandas as pd

url=r'\\192.168.0.118\d\MachineLearning\Data\boston_X.xls'
bstn=pd.read_excel(url)
bstn.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT
# 0  15.300000  396.899994   4.98
# 1  17.799999  396.899994   9.14
# 2  17.799999  392.829987   4.03
# 3  18.700001  394.630005   2.94
# 4  18.700001  396.899994   5.33

# %%
#model =pickel.loads(r'C:\Users\w10\Desktop\Hp\Boston_regressor.pkl')
#with open('Boston_regressor.pkl', 'rb') as f:
#    mdl=pickle.load(f)#@
#print(mdl)
#print(type(f))

# %%
from sklearn.externals import joblib 
#  Save model for future use
mdl=joblib.load(r'C:\Users\w10\Desktop\Hp\Boston_regressor.pkl')
print(type(mdl))
# Out:
# <class 'sklearn.linear_model.base.LinearRegression'>

# %%
bstn.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
#
#           PT           B  LSTAT
# 0  15.300000  396.899994   4.98
# 1  17.799999  396.899994   9.14
# 2  17.799999  392.829987   4.03
# 3  18.700001  394.630005   2.94
# 4  18.700001  396.899994   5.33

# %%
bstn.shape
# Out:
# (506, 13)

# %%
predt = mdl.predict(bstn)

# %%
print(predt)
# Out:
# [30.00384239 25.02556246 30.56759657 28.60703616 27.9435227  25.25628285
#  23.00180864 19.53598867 11.5236374  18.92026271 18.99949555 21.58679534
#  20.90652153 19.55290243 19.28348244 19.29748365 20.52750988 16.9114003
#  16.17801088 18.40613746 12.52385828 17.67103751 15.83288242 13.80628676
#  15.67833795 13.38668596 15.46397713 14.70847372 19.54737257 20.87642818
#  11.45511734 18.05923311  8.81105738 14.28275891 13.70675984 23.81463433
#  22.34193665 23.10890974 22.91502526 31.35762528 34.21510328 28.02056404
#  25.20386686 24.60979251 22.94149093 22.09669886 20.42319976 18.03655181
#   9.10655491 17.20607823 21.28152511 23.97222218 27.65585159 24.04901878
#  15.36184764 31.15265018 24.85686994 33.10919801 21.7753791  21.08493441
#  17.87258029 18.51110154 23.98742689 22.55408828 23.37308575 30.36148326
#  25.53056578 21.11338453 17.42153719 20.78483715 25.20148745 21.74265687
#  24.55744917 24.04295617 25.50499525 23.96692855 22.94545258 23.3569967
# ...
