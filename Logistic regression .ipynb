# %%
import pandas as pd

url=r'\\192.168.0.118\d\MachineLearning\Data\Credit.xls'
crdt=pd.read_excel(url,sheet_name='Data')
crdt.head()
# Out:
#    OBS#  CHK_ACCT  DURATION  HISTORY  NEW_CAR  USED_CAR  FURNITURE  RADIO/TV  \
# 0     1         0         6        4        0         0          0         1
# 1     2         1        48        2        0         0          0         1
# 2     3         3        12        4        0         0          0         0
# 3     4         0        42        2        0         0          1         0
# 4     5         0        24        3        1         0          0         0
#
#    EDUCATION  RETRAINING  ...  AGE  OTHER_INSTALL  RENT  OWN_RES  NUM_CREDITS  \
# 0          0           0  ...   67              0     0        1            2
# 1          0           0  ...   22              0     0        1            1
# 2          1           0  ...   49              0     0        1            1
# 3          0           0  ...   45              0     0        0            1
# 4          0           0  ...   53              0     0        0            2
#
# ...

# %%
crdt.shape
# Out:
# (1000, 32)

# %%
crdt.describe().T
# Out:
#                 count      mean          std    min      25%     50%      75%  \
# OBS            1000.0   500.500   288.819436    1.0   250.75   500.5   750.25
# CHK_ACCT       1000.0     1.577     1.257638    0.0     0.00     1.0     3.00
# DURATION       1000.0    20.903    12.058814    4.0    12.00    18.0    24.00
# HISTORY        1000.0     2.545     1.083120    0.0     2.00     2.0     4.00
# NEW_CAR        1000.0     0.234     0.423584    0.0     0.00     0.0     0.00
# USED_CAR       1000.0     0.103     0.304111    0.0     0.00     0.0     0.00
# FURNITURE      1000.0     0.181     0.385211    0.0     0.00     0.0     0.00
# RADIO/TV       1000.0     0.280     0.449224    0.0     0.00     0.0     1.00
# EDUCATION      1000.0     0.050     0.218054    0.0     0.00     0.0     0.00
# RETRAINING     1000.0     0.097     0.296106    0.0     0.00     0.0     0.00
# AMOUNT         1000.0  3271.258  2822.736876  250.0  1365.50  2319.5  3972.25
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics 

crdt.columns = crdt.columns.str.strip().str.replace('#','')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-efae27f37bf4> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn import metrics
# ----> 3 from sklearn import LogisticRegression
#       4
#       5 crdt.columns = crdt.columns.str.strip().str.replace('#','')
#
# ImportError: cannot import name 'LogisticRegression' from 'sklearn' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\__init__.py)

# %%
crdt.RESPONSE.value_counts()
# Out:
# 1    700
# 0    300
# Name: RESPONSE, dtype: int64

# %%
cedt=crdt.drop(['OBS'],axis =1)

# %%
cedt.corr()
# Out:
#                CHK_ACCT  DURATION   HISTORY   NEW_CAR  USED_CAR  FURNITURE  \
# CHK_ACCT       1.000000 -0.072013  0.192191 -0.069559  0.064303  -0.098016
# DURATION      -0.072013  1.000000 -0.077186 -0.109999  0.144939  -0.062804
# HISTORY        0.192191 -0.077186  1.000000  0.042480  0.039096  -0.025539
# NEW_CAR       -0.069559 -0.109999  0.042480  1.000000 -0.187291  -0.259831
# USED_CAR       0.064303  0.144939  0.039096 -0.187291  1.000000  -0.159301
# FURNITURE     -0.098016 -0.062804 -0.025539 -0.259831 -0.159301   1.000000
# RADIO/TV       0.110632 -0.044319  0.021396 -0.344672 -0.211317  -0.293164
# EDUCATION      0.007848  0.003750  0.054039 -0.126799 -0.077740  -0.107850
# RETRAINING     0.021587  0.164113 -0.090091 -0.181149 -0.111062  -0.154078
# AMOUNT        -0.042705  0.624984 -0.059905 -0.040793  0.252101  -0.034037
# SAV_ACCT       0.222867  0.047661  0.039058 -0.002348  0.112880  -0.082241
# ...

# %%
x = cedt[list(cedt.columns)[:-1]]
y = cedt['RESPONSE']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,random_state=0)

# %%
x_train.head()
# Out:
#      CHK_ACCT  DURATION  HISTORY  NEW_CAR  USED_CAR  FURNITURE  RADIO/TV  \
# 732         1         8        2        0         0          0         1
# 398         1        12        2        1         0          0         0
# 933         3        12        4        0         0          0         1
# 72          0         8        4        0         0          0         0
# 340         1        24        4        0         0          0         0
#
#      EDUCATION  RETRAINING  AMOUNT  ...  PROP_NONE  AGE  OTHER_INSTALL  RENT  \
# 732          0           0     760  ...          0   44              0     0
# 398          0           0    1223  ...          0   46              0     1
# 933          0           0     522  ...          0   42              0     0
# 72           0           0    1164  ...          1   51              1     0
# 340          1           0    5743  ...          1   24              0     0
#
#      OWN_RES  NUM_CREDITS  JOB  NUM_DEPEND  TELEPHONE  FOREIGN
# ...

# %%
y_train.head()
# Out:
# 732    1
# 398    0
# 933    1
# 72     1
# 340    1
# Name: RESPONSE, dtype: int64

# %%
from sklearn.linear_model.logistic import LogisticRegression

model= LogisticRegression(solver='liblinear',max_iter=100)
l1reg=model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print("accuracy :\n", metrics.accuracy_score(y_test,y_pred))
print("classification:\n", metrics.classification_report(y_test,y_pred))
print("confusion matrix:\n", metrics.confusion_matrix(y_test,y_pred))
# Out:
# accuracy :
#  0.78
# classification:
#                precision    recall  f1-score   support
#
#            0       0.70      0.47      0.56        75
#            1       0.80      0.91      0.85       175
#
#    micro avg       0.78      0.78      0.78       250
#    macro avg       0.75      0.69      0.71       250
# weighted avg       0.77      0.78      0.77       250
#
# confusion matrix:
#  [[ 35  40]
#  [ 15 160]]

# %%
url=r'\\192.168.0.118\d\MachineLearning\Data\iris.csv'
iris=pd.read_csv(url)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from sklearn.linear_model.logistic import LogisticRegression

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = iris[list(iris.columns)[:-1]]
y = iris['species']

# %%
ix_train,ix_test,iy_train,iy_test=train_test_split(x,y,stratify=y,random_state=0)

# %%
iy_train.head()
# Out:
# 60     versicolor
# 1          setosa
# 8          setosa
# 93     versicolor
# 106     virginica
# Name: species, dtype: object

# %%
ix_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 60            5.0          2.0           3.5          1.0
# 1             4.9          3.0           1.4          0.2
# 8             4.4          2.9           1.4          0.2
# 93            5.0          2.3           3.3          1.0
# 106           4.9          2.5           4.5          1.7

# %%
model= LogisticRegression(solver='liblinear')
l1reg=model.fit(ix_train,iy_train)
iy_pred=model.predict(ix_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
print("accuracy :\n", metrics.accuracy_score(iy_test,iy_pred))
print("classification:\n", metrics.classification_report(iy_test,iy_pred))
print("confusion matrix:\n", metrics.confusion_matrix(iy_test,iy_pred))
# Out:
# accuracy :
#  0.9736842105263158
# classification:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.92      1.00      0.96        12
#
#    micro avg       0.97      0.97      0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
# confusion matrix:
#  [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
